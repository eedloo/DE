# %%
import pandas as pd

# %%
pd.read_pickle(r'D:\SLU\AI MSc\Repos\DE\project2\tmph_10vas5\storage\analytic_car_data')
# Out:
#             ID  Price Levy Manufacturer       Model Prod. year   Category  \
# 0     26556811     60    -       TOYOTA       Prius       2012  Hatchback
# 1     32089280     50    -       TOYOTA        Aqua       2012      Sedan
# 2     32116317     50    -       TOYOTA        Aqua       2013      Sedan
# 3     32495123  16621    -       TOYOTA     Prius C       2012  Hatchback
# 4     32608049     50    -       TOYOTA        Aqua       2013  Hatchback
# ...        ...    ...  ...          ...         ...        ...        ...
# 5398  45816615    941  900      HYUNDAI    Santa FE       2015       Jeep
# 5399  45816620   1333  697      HYUNDAI     Elantra       2015      Sedan
# 5400  45816638  13799  528         FORD  Fiesta 1.6       2014  Hatchback
# 5401  45816646  14740  645       TOYOTA       Prius       2011  Hatchback
# 5402  45816650  20698  697       TOYOTA       Auris       2015  Hatchback
#
#      Leather interior Fuel type Engine volume  ... Percentile  NA PPG NA DP  \
# ...
