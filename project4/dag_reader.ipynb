# %%
import pandas as pd
pd.read_pickle(r"D:\SLU\AI MSc\Repos\DE\project4\tmpqwno969k\storage\make_final_df")
# Out:
# c:\Users\mae85\anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# c:\Users\mae85\anaconda3\lib\site-packages\numpy\.libs\libopenblas.FB5AE2TYXYH2IJRDKGDGQ3XBKLKTF43H.gfortran-win_amd64.dll
# c:\Users\mae85\anaconda3\lib\site-packages\numpy\.libs\libopenblas.XWYDX2IKJW2NMTWSFYNGFUWKQU3LYTCZ.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"
#        restaurant_id  position                              name  \
# 0                  1        19                          PJ Fresh
# 1                 24        32        Cinnabon baked at Flying J
# 2                164        59      Cosmic Wings - 5 Points West
# 3                171        51                           Denny's
# 4                  3         6         Philly Fresh Cheesesteaks
# ...              ...       ...                               ...
# 32650          40031       277         New Sitara Indian Cuisine
# ...
