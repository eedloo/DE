# %%
import pandas as pd
# Out:
# c:\Users\mae85\anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# c:\Users\mae85\anaconda3\lib\site-packages\numpy\.libs\libopenblas.FB5AE2TYXYH2IJRDKGDGQ3XBKLKTF43H.gfortran-win_amd64.dll
# c:\Users\mae85\anaconda3\lib\site-packages\numpy\.libs\libopenblas.XWYDX2IKJW2NMTWSFYNGFUWKQU3LYTCZ.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
pd.read_pickle(r'.\tmprk1mfmsv\storage\make_final_df')
# Out:
#          verdict  news  world  health  business  realDonaldTrump  death  \
# 0           True     5     33     107        40                0     41
# 1    Mostly-True     4     80     159        64                3     30
# 2      Half-True     5     48     201        53                1     30
# 3   Mostly-False     8     33     198        49                0     39
# 4          False    29     64     203        69                3     81
# 5  Pants-on-Fire    11     36      96        22                0     35
#
#    attack  work  crime  ...  vote  state  officer  money  fire  law  police  \
# 0      15    75     32  ...   162    326       12     50    23  115      14
# 1      14   152     51  ...   211    389       18     76    56  134      33
# 2      27   193     62  ...   241    371       17    105    37  153      31
# 3      27   138     43  ...   258    288       12     98    33  167      29
# 4      54   172     36  ...   326    341       39    108    69  202      84
# ...
